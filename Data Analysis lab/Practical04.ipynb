# %% [markdown]
# # Data Analytics Lab
#
# ## Practical 04: Relationship Between Study Hours and Exam Scores using Linear Regression
#
# ### Objective
# To analyze the relationship between study hours and exam scores using Linear Regression and predict exam scores based on study hours.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = {
    "Study_Hours": [1, 2, 3, 4, 5, 6, 7, 8],
    "Exam_Score": [35, 40, 50, 55, 65, 70, 80, 90]
}

df = pd.DataFrame(data)

df
# Out:
#    Study_Hours  Exam_Score
# 0            1          35
# 1            2          40
# 2            3          50
# 3            4          55
# 4            5          65
# 5            6          70
# 6            7          80
# 7            8          90

# %%
X = df[["Study_Hours"]]
y = df["Exam_Score"]

# %%
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
predicted_scores = model.predict(X)

predicted_scores
# Out:
# array([33.33333333, 41.13095238, 48.92857143, 56.72619048, 64.52380952,
#        72.32142857, 80.11904762, 87.91666667])

# %%
plt.scatter(X, y)

plt.plot(X, predicted_scores)

plt.xlabel("Study Hours")

plt.ylabel("Exam Score")

plt.title("Study Hours vs Exam Score")

plt.show()

# %%
hours = [[9]]

predicted = model.predict(hours)

print("Predicted score for 9 hours study:", predicted[0])
# Out:
# Predicted score for 9 hours study: 95.71428571428572
# c:\Users\ASAWARI\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Result
#
# Successfully analyzed the relationship between study hours and exam scores using Linear Regression and predicted exam scores based on study hours.
